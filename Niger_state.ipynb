# %% [markdown]
# <a href="https://colab.research.google.com/github/Husayn01/GIS-Projects/blob/main/Niger_state.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-fd74f49e-ef38-4d2f-bfa2-f38b9b8dc684" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fd74f49e-ef38-4d2f-bfa2-f38b9b8dc684">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import geopandas as gpd

niger_state = gpd.read_file("niger_state.shp")

# %%
import folium

# Get the center of Niger State for the map

# Create a Folium map centered on Niger State
center = [niger_state.geometry.centroid.y.mean(), niger_state.geometry.centroid.x.mean()]

# Create a Folium map centered on Niger State
m = folium.Map(location=center, zoom_start=8)

# Add the Niger State shapefile to the map with labels
def style_function(feature):
    return {
        'fillColor': 'blue',
        'color': 'black',
        'weight': 1,
        'fillOpacity': 0.5,
    }

# Add GeoJson with popups for labels
folium.GeoJson(
    niger_state,
    style_function=style_function,
    popup=folium.GeoJsonPopup(fields=['NAME_2'], labels=True)  # Change 'your_label_field' to the actual field name for labels
).add_to(m)

# Display the map
m
# Out:
# <ipython-input-10-647cf39e3055>:6: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   center = [niger_state.geometry.centroid.y.mean(), niger_state.geometry.centroid.x.mean()]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
# ...
